# %%
from monai.utils import first, set_determinism
from monai.transforms import(
    Compose,
    AddChanneld,
    LoadImaged,
    Resized,
    ToTensord,
    Spacingd,
    Orientationd,
    ScaleIntensityRanged,
    CropForegroundd,
    Activations,
)

from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.data import CacheDataset, DataLoader, Dataset

import torch
import matplotlib.pyplot as plt

import os
from glob import glob
import numpy as np

from monai.inferers import sliding_window_inference

# %%
in_dir = 'E:/data_set'
model_dir = 'C:/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch'

# %%
train_loss = np.load(os.path.join(model_dir, 'loss_train.npy'))
train_metric = np.load(os.path.join(model_dir, 'metric_train.npy'))
test_loss = np.load(os.path.join(model_dir, 'loss_test.npy'))
test_metric = np.load(os.path.join(model_dir, 'metric_test.npy'))

# %%
plt.figure("Results 6 june", (12, 6))
plt.subplot(2, 2, 1)
plt.title("Train dice loss")
x = [i + 1 for i in range(len(train_loss))]
y = train_loss
plt.xlabel("epoch")
plt.plot(x, y)

plt.subplot(2, 2, 2)
plt.title("Train metric DICE")
x = [i + 1 for i in range(len(train_metric))]
y = train_metric
plt.xlabel("epoch")
plt.plot(x, y)

plt.subplot(2, 2, 3)
plt.title("Test dice loss")
x = [i + 1 for i in range(len(test_loss))]
y = test_loss
plt.xlabel("epoch")
plt.plot(x, y)

plt.subplot(2, 2, 4)
plt.title("Test metric DICE")
x = [i + 1 for i in range(len(test_metric))]
y = test_metric
plt.xlabel("epoch")
plt.plot(x, y)

plt.show()

# %%
path_train_volumes = sorted(glob(os.path.join(in_dir, "TrainVolumes", "*.nii.gz")))
path_train_segmentation = sorted(glob(os.path.join(in_dir, "TrainSegmentation", "*.nii.gz")))

path_test_volumes = sorted(glob(os.path.join(in_dir, "TestVolumes", "*.nii.gz")))
path_test_segmentation = sorted(glob(os.path.join(in_dir, "TestSegmentation", "*.nii.gz")))

train_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in zip(path_train_volumes, path_train_segmentation)]
test_files = [{"vol": image_name, "seg": label_name} for image_name, label_name in zip(path_test_volumes, path_test_segmentation)]
test_files = test_files[0:9]

# %%
test_transforms = Compose(
    [
        LoadImaged(keys=["vol", "seg"]),
        AddChanneld(keys=["vol", "seg"]),
        Spacingd(keys=["vol", "seg"], pixdim=(1.5,1.5,1.0), mode=("bilinear", "nearest")),
        Orientationd(keys=["vol", "seg"], axcodes="RAS"),
        ScaleIntensityRanged(keys=["vol"], a_min=-200, a_max=200,b_min=0.0, b_max=1.0, clip=True), 
        CropForegroundd(keys=['vol', 'seg'], source_key='vol'),
        Resized(keys=["vol", "seg"], spatial_size=[128,128,64]),   
        ToTensord(keys=["vol", "seg"]),
    ]
)

# %%
test_ds = Dataset(data=test_files, transform=test_transforms)
test_loader = DataLoader(test_ds, batch_size=1)

# %%
device = torch.device("cuda:0")
model = UNet(
    dimensions=3,
    in_channels=1,
    out_channels=2,
    channels=(16, 32, 64, 128, 256), 
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Gaming\Liver-Segmentation-Using-Monai-and-PyTorch\testing.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=0'>1</a> device = torch.device("cuda:0")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=1'>2</a> model = UNet(
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=2'>3</a>     dimensions=3,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=3'>4</a>     in_channels=1,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=4'>5</a>     out_channels=2,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=5'>6</a>     channels=(16, 32, 64, 128, 256),
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=6'>7</a>     strides=(2, 2, 2, 2),
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=7'>8</a>     num_res_units=2,
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=8'>9</a>     norm=Norm.BATCH,
#      <a href='vscode-notebook-cell:/c%3A/Users/Gaming/Liver-Segmentation-Using-Monai-and-PyTorch/testing.ipynb#ch0000007?line=9'>10</a> ).to(device)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\utils\deprecate_utils.py:217, in deprecated_arg.<locals>._decorator.<locals>._wrapper(*args, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=213'>214</a>     if is_deprecated:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=214'>215</a>         warn_deprecated(argname, msg)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=216'>217</a> return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:191, in UNet.__init__(self, spatial_dims, in_channels, out_channels, channels, strides, kernel_size, up_kernel_size, num_res_units, act, norm, dropout, bias, dimensions)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=186'>187</a>     up = self._get_up_layer(upc, outc, s, is_top)  # create layer in upsampling path
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=188'>189</a>     return nn.Sequential(down, SkipConnection(subblock), up)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=190'>191</a> self.model = _create_block(in_channels, out_channels, self.channels, self.strides, True)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:179, in UNet.__init__.<locals>._create_block(inc, outc, channels, strides, is_top)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=175'>176</a> subblock: nn.Module
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=177'>178</a> if len(channels) > 2:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=178'>179</a>     subblock = _create_block(c, c, channels[1:], strides[1:], False)  # continue recursion down
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=179'>180</a>     upc = c * 2
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=180'>181</a> else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=181'>182</a>     # the next layer is the bottom so stop recursion, create the bottom layer as the sublock for this layer
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:179, in UNet.__init__.<locals>._create_block(inc, outc, channels, strides, is_top)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=175'>176</a> subblock: nn.Module
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=177'>178</a> if len(channels) > 2:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=178'>179</a>     subblock = _create_block(c, c, channels[1:], strides[1:], False)  # continue recursion down
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=179'>180</a>     upc = c * 2
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=180'>181</a> else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=181'>182</a>     # the next layer is the bottom so stop recursion, create the bottom layer as the sublock for this layer
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:179, in UNet.__init__.<locals>._create_block(inc, outc, channels, strides, is_top)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=175'>176</a> subblock: nn.Module
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=177'>178</a> if len(channels) > 2:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=178'>179</a>     subblock = _create_block(c, c, channels[1:], strides[1:], False)  # continue recursion down
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=179'>180</a>     upc = c * 2
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=180'>181</a> else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=181'>182</a>     # the next layer is the bottom so stop recursion, create the bottom layer as the sublock for this layer
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:183, in UNet.__init__.<locals>._create_block(inc, outc, channels, strides, is_top)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=179'>180</a>     upc = c * 2
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=180'>181</a> else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=181'>182</a>     # the next layer is the bottom so stop recursion, create the bottom layer as the sublock for this layer
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=182'>183</a>     subblock = self._get_bottom_layer(c, channels[1])
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=183'>184</a>     upc = c + channels[1]
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=185'>186</a> down = self._get_down_layer(inc, c, s, is_top)  # create layer in downsampling path
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:236, in UNet._get_bottom_layer(self, in_channels, out_channels)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=229'>230</a> def _get_bottom_layer(self, in_channels: int, out_channels: int) -> nn.Module:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=230'>231</a>     """
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=231'>232</a>     Args:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=232'>233</a>         in_channels: number of input channels.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=233'>234</a>         out_channels: number of output channels.
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=234'>235</a>     """
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=235'>236</a>     return self._get_down_layer(in_channels, out_channels, 1, False)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\nets\unet.py:204, in UNet._get_down_layer(self, in_channels, out_channels, strides, is_top)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=200'>201</a> mod: nn.Module
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=201'>202</a> if self.num_res_units > 0:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=203'>204</a>     mod = ResidualUnit(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=204'>205</a>         self.dimensions,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=205'>206</a>         in_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=206'>207</a>         out_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=207'>208</a>         strides=strides,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=208'>209</a>         kernel_size=self.kernel_size,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=209'>210</a>         subunits=self.num_res_units,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=210'>211</a>         act=self.act,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=211'>212</a>         norm=self.norm,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=212'>213</a>         dropout=self.dropout,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=213'>214</a>         bias=self.bias,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=214'>215</a>     )
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=215'>216</a>     return mod
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=216'>217</a> mod = Convolution(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=217'>218</a>     self.dimensions,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=218'>219</a>     in_channels,
#    (...)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=225'>226</a>     bias=self.bias,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/nets/unet.py?line=226'>227</a> )
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\utils\deprecate_utils.py:217, in deprecated_arg.<locals>._decorator.<locals>._wrapper(*args, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=213'>214</a>     if is_deprecated:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=214'>215</a>         warn_deprecated(argname, msg)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=216'>217</a> return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\blocks\convolutions.py:288, in ResidualUnit.__init__(self, spatial_dims, in_channels, out_channels, strides, kernel_size, subunits, adn_ordering, act, norm, dropout, dropout_dim, dilation, bias, last_conv_only, padding, dimensions)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=285'>286</a> for su in range(subunits):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=286'>287</a>     conv_only = last_conv_only and su == (subunits - 1)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=287'>288</a>     unit = Convolution(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=288'>289</a>         self.dimensions,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=289'>290</a>         schannels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=290'>291</a>         out_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=291'>292</a>         strides=sstrides,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=292'>293</a>         kernel_size=kernel_size,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=293'>294</a>         adn_ordering=adn_ordering,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=294'>295</a>         act=act,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=295'>296</a>         norm=norm,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=296'>297</a>         dropout=dropout,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=297'>298</a>         dropout_dim=dropout_dim,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=298'>299</a>         dilation=dilation,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=299'>300</a>         bias=bias,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=300'>301</a>         conv_only=conv_only,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=301'>302</a>         padding=padding,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=302'>303</a>     )
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=304'>305</a>     self.conv.add_module(f"unit{su:d}", unit)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=306'>307</a>     # after first loop set channels and strides to what they should be for subsequent units
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\utils\deprecate_utils.py:217, in deprecated_arg.<locals>._decorator.<locals>._wrapper(*args, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=213'>214</a>     if is_deprecated:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=214'>215</a>         warn_deprecated(argname, msg)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/utils/deprecate_utils.py?line=216'>217</a> return func(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\monai\networks\blocks\convolutions.py:149, in Convolution.__init__(self, spatial_dims, in_channels, out_channels, strides, kernel_size, adn_ordering, act, norm, dropout, dropout_dim, dilation, groups, bias, conv_only, is_transposed, padding, output_padding, dimensions)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=136'>137</a>     conv = conv_type(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=137'>138</a>         in_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=138'>139</a>         out_channels,
#    (...)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=145'>146</a>         dilation=dilation,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=146'>147</a>     )
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=147'>148</a> else:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=148'>149</a>     conv = conv_type(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=149'>150</a>         in_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=150'>151</a>         out_channels,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=151'>152</a>         kernel_size=kernel_size,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=152'>153</a>         stride=strides,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=153'>154</a>         padding=padding,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=154'>155</a>         dilation=dilation,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=155'>156</a>         groups=groups,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=156'>157</a>         bias=bias,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=157'>158</a>     )
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=159'>160</a> self.add_module("conv", conv)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/monai/networks/blocks/convolutions.py?line=161'>162</a> if not conv_only:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:570, in Conv3d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=567'>568</a> padding_ = padding if isinstance(padding, str) else _triple(padding)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=568'>569</a> dilation_ = _triple(dilation)
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=569'>570</a> super(Conv3d, self).__init__(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=570'>571</a>     in_channels, out_channels, kernel_size_, stride_, padding_, dilation_,
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=571'>572</a>     False, _triple(0), groups, bias, padding_mode, **factory_kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:131, in _ConvNd.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=127'>128</a>     self.weight = Parameter(torch.empty(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=128'>129</a>         (in_channels, out_channels // groups, *kernel_size), **factory_kwargs))
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=129'>130</a> else:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=130'>131</a>     self.weight = Parameter(torch.empty(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=131'>132</a>         (out_channels, in_channels // groups, *kernel_size), **factory_kwargs))
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=132'>133</a> if bias:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/conv.py?line=133'>134</a>     self.bias = Parameter(torch.empty(out_channels, **factory_kwargs))
#
# File c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py:1203, in Module.__setattr__(self, name, value)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1199'>1200</a>         raise AttributeError(
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1200'>1201</a>             "cannot assign parameters before Module.__init__() call")
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1201'>1202</a>     remove_from(self.__dict__, self._buffers, self._modules, self._non_persistent_buffers_set)
# -> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1202'>1203</a>     self.register_parameter(name, value)
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1203'>1204</a> elif params is not None and name in params:
#    <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=1204'>1205</a>     if value is not None:
#
# File c:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py:345, in Module.register_parameter(self, name, param)
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=340'>341</a> if '_parameters' not in self.__dict__:
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=341'>342</a>     raise AttributeError(
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=342'>343</a>         "cannot assign parameter before Module.__init__() call")
# --> <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=344'>345</a> elif not isinstance(name, torch._six.string_classes):
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=345'>346</a>     raise TypeError("parameter name should be a string. "
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=346'>347</a>                     "Got {}".format(torch.typename(name)))
#     <a href='file:///c%3A/ProgramData/Anaconda3/lib/site-packages/torch/nn/modules/module.py?line=347'>348</a> elif '.' in name:
#
# AttributeError: module 'torch' has no attribute '_six'

# %%
model.load_state_dict(torch.load(
    os.path.join(model_dir, "best_metric_model.pth")))
model.eval()

# %%
sw_batch_size = 4
roi_size = (128, 128, 64)
with torch.no_grad():
    test_patient = first(test_loader)
    t_volume = test_patient['vol']
    #t_segmentation = test_patient['seg']
    
    test_outputs = sliding_window_inference(t_volume.to(device), roi_size, sw_batch_size, model)
    sigmoid_activation = Activations(sigmoid=True)
    test_outputs = sigmoid_activation(test_outputs)
    test_outputs = test_outputs > 0.53
        
    for i in range(32):
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(test_patient["vol"][0, 0, :, :, i], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(test_patient["seg"][0, 0, :, :, i] != 0)
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(test_outputs.detach().cpu()[0, 1, :, :, i])
        plt.show()
